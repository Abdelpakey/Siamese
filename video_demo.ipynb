# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
cap = cv2.VideoCapture("input_video.mp4")

# %%
while True:
    ret, img = cap.read()
    break

# %%
plt.imshow(img)

# %%
xmin, ymin, box_width, box_height = [910,366,80,322]

# %%
box_width
# Out:
# 80

# %%
img = cv2.rectangle(img,
                   (xmin, ymin),
                   (xmin + box_width, ymin + box_height),
                   (255, 0, 0),
                   3)

# %%
plt.imshow(img)

# %%
f = open('input_label.txt')

# %%
f.read().strip()
# Out:
# '910,366,80,322'
